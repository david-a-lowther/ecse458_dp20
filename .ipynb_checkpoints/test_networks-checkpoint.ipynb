# %% [markdown]
# Notebook for testing nn performance

# %%
# import dependencies
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from data_preprocessing import extract_csv_info, format_data, shuffle_and_split, split_input_output
from neural import train_and_generate_feedforward_network, train_and_generate_recurrent_network, train_and_generate_preisach_network, train_and_generate_recurrent_preisach_network

# %%
# Function to compute MSE of predicted values
def compute_mse(actual_y, predicted_y):
    actual_y = np.asarray(actual_y)
    predicted_y = np.asarray(predicted_y)
    diff = np.subtract(actual_y, predicted_y)
    squared = np.square(diff)
    mse = np.mean(squared)
    return mse


# test compute mse
# y = [11, 20, 19, 17, 10]
# y_pred = [12, 18, 19.5, 18, 9]
# print(compute_mse(y, y_pred))

# %%
# Function for plotting predicted values from NN
# TODO: add figsize and xlim as input to function to allow customization
def plot_predicted(next_h, next_b, model_name):
    plt.figure(figsize=(20, 12))
    plt.xlim(-750, 750)
    plt.plot(next_h, next_b, marker="o", color='black')
    plt.title(model_name + " Output Plot")
    plt.xlabel("Magnetic Field H (T)")
    plt.ylabel("Magnetic Flux B (A/m)")
    plt.show()

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
# Load data for training
raw_train_data = extract_csv_info("./data_simulated/M19_29Gauge - Sheet1.csv")
# format into (current H, current B, next H, next B)
formatted_data = format_data(raw_train_data)
#train, test = shuffle_and_split(formatted_data)
train_x, train_y = split_input_output(formatted_data)
#test_x, test_y = split_input_output(test)

# %%
# Load data for testing
raw_test_data = extract_csv_info("./data_simulated/M19_TESTINGDATA - M19_TESTINGDATA.csv")
formatted_test_data = format_data(raw_test_data)
test_x, test_y = split_input_output(formatted_test_data)

# Separate next_h values into separate list for plotting output
test_next_h = list()
for i in range(len(test_x)):
    test_next_h.append(test_x[i][2])

# %% [markdown]
# ## Feedforward Network

# %%
# Generate and train feedforward network
feedforward_model = train_and_generate_feedforward_network(train_x, train_y, "feedforward.model", n_epochs=20)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 4ms/step - loss: 0.3139 - mean_squared_error: 0.3139
# Epoch 2/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 3/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 4/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 5/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 6/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 7/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 8/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 9/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0108 - mean_squared_error: 0.0108
# Epoch 10/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 11/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 12/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 13/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 14/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 15/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 16/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 17/20
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 18/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 19/20
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 20/20
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_squared_error: 0.0068
# INFO:tensorflow:Assets written to: models/feedforward.model\assets

# %%
# Load feedforward model
feedforward_model = tf.keras.models.load_model("./models/feedforward.model")

# %%
# Evaluate feedforward network
feedforward_prediction = feedforward_model.predict(test_x)
mse = compute_mse(test_y, feedforward_prediction)
print("MSE: " + str(mse))

# tensorflow evaluation
feedforward_model.evaluate(test_x, test_y)
# Out:
# 37/37 [==============================] - 0s 1ms/step
# MSE: 0.7957188296042831
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0499 - mean_squared_error: 0.0499
# [0.04985468089580536, 0.04985468089580536]

# %%
# Plot feedforward output
plot_predicted(test_next_h, feedforward_prediction, "Feedforward Network")

# %% [markdown]
# ## Preisach Network

# %%
# Generate and train preisach network
pnn_model = train_and_generate_preisach_network(train_x, train_y, "preisach.model", n_epochs=20)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 3ms/step - loss: 0.0884 - mean_squared_error: 0.0884
# Epoch 2/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0310 - mean_squared_error: 0.0310
# Epoch 3/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Epoch 4/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0306 - mean_squared_error: 0.0306
# Epoch 5/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_squared_error: 0.0291
# Epoch 6/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Epoch 7/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_squared_error: 0.0291
# Epoch 8/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Epoch 9/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Epoch 10/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0284 - mean_squared_error: 0.0284
# Epoch 11/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0287 - mean_squared_error: 0.0287
# Epoch 12/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0279 - mean_squared_error: 0.0279
# Epoch 13/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0257 - mean_squared_error: 0.0257
# Epoch 14/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0253 - mean_squared_error: 0.0253
# Epoch 15/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0255 - mean_squared_error: 0.0255
# Epoch 16/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_squared_error: 0.0240
# Epoch 17/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0247 - mean_squared_error: 0.0247
# Epoch 18/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0220 - mean_squared_error: 0.0220
# Epoch 19/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0214 - mean_squared_error: 0.0214
# Epoch 20/20
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0217 - mean_squared_error: 0.0217
# INFO:tensorflow:Assets written to: models/preisach.model\assets

# %%
# Load preisach model
pnn_model = tf.keras.models.load_model("./models/preisach.model")

# %%
#Evaluate preisach model
pnn_prediction = pnn_model.predict(test_x)
mse = compute_mse(test_y, pnn_prediction)
print("MSE: " + str(mse))

# tensorflow evaluation
pnn_model.evaluate(test_x, test_y)

# Plot Preisach output
plot_predicted(test_next_h, pnn_prediction, "Preisach Network")
# Out:
# 37/37 [==============================] - 0s 2ms/step
# MSE: 0.9001205983426747
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0281 - mean_squared_error: 0.0281

# %% [markdown]
# ## Recurrent Network
# no stop activation layer

# %%
# Generate and train recurrent network (no stop operator)
rnn_model = train_and_generate_recurrent_network(train_x, train_y, "recurrent.model", n_epochs=20)

# %%
# Load recurrent network
rnn_model = tf.keras.models.load_model("./models/recurrent.model")

# %%
# Evaluate recurrent model
rnn_prediction = rnn_model.predict(test_x)
mse = compute_mse(test_y, rnn_prediction)
print("MSE: " + str(mse))

# tensorflow evaluation
rnn_model.evaluate(test_x, test_y)

# %% [markdown]
# ## Recurrent Preisach Network
# includes stop activation layer

# %%
# Generate and train recurrent preisach network
rnn_model = train_and_generate_recurrent_preisach_network(train_x, train_y, "recurrent_preisach.model", n_epochs=20)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'dense_1/kernel:0', 'dense_1/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'dense_1/kernel:0', 'dense_1/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
